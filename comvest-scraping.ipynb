# %%
import requests

host = "http://www.comvest.unicamp.br/vestibulares-anteriores/1a-fase-2a-fase-comentadas/"
page = requests.get(host, timeout=5)
# print(page.text)
# print(page.content) # html source

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(page.content, 'html.parser') # 'lxml'
# print(soup.prettify())

# list(soup.children)
[type(item) for item in list(soup.children)]
# Out:
# [bs4.element.Doctype,
#  bs4.element.Tag,
#  bs4.element.NavigableString,
#  bs4.element.Comment]

# %%
# html = list(soup.children)[2]
# len(list(html.children))
all_links = set()
for link in soup.find_all():
    link_string = link.get('href')
    all_links.add(link_string)
#     if(link_string != None):
#         print(link_string)
print(all_links)
# Out:
# {'/vest_anteriores/2005/download/comentadas/historia.pdf', '/vest_anteriores/2000/download/comentadas/Desempenho.pdf', '/vest_anteriores/2010/download/comentadas/historia.pdf', '/vest_anteriores/2008/download/comentadas/biologia.pdf', '/vest_anteriores/2004/download/comentadas/ingles.pdf', '/vest_anteriores/2002/download/comentadas/CBiologicas.pdf', 'http://www.comvest.unicamp.br/wp-json/oembed/1.0/embed?url=http%3A%2F%2Fwww.comvest.unicamp.br%2Fvestibulares-anteriores%2F1a-fase-2a-fase-comentadas%2F', 'http://www.comvest.unicamp.br/vestibulares-anteriores/vestibular-2004/', '/vest_anteriores/2001/download/comentadas/Musica.pdf', '/vest_anteriores/2003/download/comentadas/Danca.pdf', 'http://www.comvest.unicamp.br/informacoes-contato/cadastre-sua-escola/', '/vest_anteriores/2000/download/comentadas/Fisica.pdf', '/vest_anteriores/2004/download/comentadas/matematica.pdf', 'https://www.comvest.unicamp.br/xmlrpc.php?rsd', '/vest_anteriores/2006/download/comentadas/quimica.pdf', 'https://maxcdn.bootstrapcdn.com/bootstrap/3.3.2/css/bootstrap.min.css?ver=5.0.3', 'https://www.facebook.com/vestibular.unicamp', '/vest_anteriores/2002/download/comentadas/Danca.pdf', 'http://www.comvest.unicamp.br/vestibulares-anteriores/vestibular-1999/', 'http://www.comvest.unicamp.br/categoria/noticias/', '/vest_anteriores/2005/download/comentadas/quimica.pdf', '/vest_anteriores/2016/download/comentadas/F2_quimica.pdf', '/vest_anteriores/2007/download/comentadas/fase1.pdf', 'http://www.comvest.unicamp.br/wp-content/uploads/2018/10/cropped-comvest-1-192x192.png', '/vest_anteriores/2016/download/comentadas/F2_geografia.pdf', '/vest_anteriores/2003/download/comentadas/musica/Percepcao_Oral.pdf', 'http://www.comvest.unicamp.br/wp-content/plugins/ultimate-posts-widget/css/upw-theme-standard.min.css?ver=5.0.3', 'http://www.comvest.unicamp.br/vestibulares-anteriores/vestibular-2009/', '/vest_anteriores/2017/download/comentadas/F2_biologia.pdf', '/vest_anteriores/2014/download/comentadas/cenicas.pdf', '/vest_anteriores/1998/download/comentadas/CadernoQuestoes_fase1.pdf', '/vest_anteriores/2013/download/comentadas/artes_visuais.pdf', 'http://www.comvest.unicamp.br/informacoes-contato', 'http://www.comvest.unicamp.br/vagas-remanescentes-2019/', '/vest_anteriores/2016/download/comentadas/F1_quimica.pdf', 'http://www.comvest.unicamp.br/vestibulares-anteriores/vestibular-1997-03/', '/vest_anteriores/2006/download/comentadas/ed_artistica.pdf', '/vest_anteriores/2002/download/comentadas/Cenicas.pdf', '/vest_anteriores/2010/download/comentadas/artes_visuais.pdf', '/vest_anteriores/2013/download/comentadas/danca.pdf', '/vest_anteriores/2012/download/comentadas/ingles.pdf', '/vest_anteriores/2013/download/comentadas/redacao.pdf', '/vest_anteriores/2015/download/comentadas/geografia.pdf', 'http://www.comvest.unicamp.br/wp-content/themes/comvest/style.css?ver=5.0.3', '/vest_anteriores/2000/download/comentadas/Quimica.pdf', '/vest_anteriores/2007/download/comentadas/arquitetura.pdf', '/vest_anteriores/2017/download/comentadas/F2_fisica.pdf', '/vest_anteriores/2003/download/comentadas/musica/Composicao.pdf', '/vest_anteriores/2011/download/comentadas/portugues.pdf', '/vest_anteriores/2010/download/comentadas/cenicas.pdf', 'http://www.comvest.unicamp.br/vestibulares-anteriores/vestibular-1997-04/', 'http://www.comvest.unicamp.br/vestibulares-anteriores/vestibular-1997-05/', 'http://www.comvest.unicamp.br/inclusao-paais/isencao/', '/vest_anteriores/2000/download/comentadas/Matematica.pdf', '/vest_anteriores/2018/download/comentadas/F2_fisica.pdf', 'mailto:?subject=Provas%20Comentadas%20por%20Ano&body=Envie%20um%20email%20com%20este%20link%20http://www.comvest.unicamp.br/vestibulares-anteriores/1a-fase-2a-fase-comentadas/', '/vest_anteriores/2001/download/comentadas/Artes_Cenicas.pdf', '/vest_anteriores/2017/download/comentadas/F2_historia.pdf', '/vest_anteriores/2006/download/comentadas/fisica.pdf', '/vest_anteriores/2017/download/comentadas/F1_geografia.pdf', '/vest_anterior ...

# %%
a = [1,2,1,3]
print(a)
3 not in a
print(a.pop(0))
a.push(5)
print(a)
# Out:
# [1, 2, 1, 3]
# 1
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-53-0f1bea33015b> in <module>
#       3 3 not in a
#       4 print(a.pop(0))
# ----> 5 a.push(5)
#       6 print(a)
#
# AttributeError: 'list' object has no attribute 'push'
